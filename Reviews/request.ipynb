# %%
import requests
import pickle as pkl
from time import sleep
from tqdm import tqdm
import pandas as pd 
from bs4 import BeautifulSoup
import cloudscraper 

def parse(html):
    """Parses the HTML for the price of the product."""
    soup = BeautifulSoup(html, 'html.parser')
    try:
        # Find the span element with the class "product-price"
        output = soup.find('span', class_='common__EiReviewDetailsStyle__newUiJobLine').text
        return output
    except:
        print("Error parsing for location")

# %%
API_TOKEN = input("Enter your API token: ")

# %%
dataset = []

# %% [markdown]
# ### Pool the reviews
# This code is used to pool the reviews and create a CSV file (for each company separatelly). We keep only *US-based* and *English* reviews.

# %%
url = "https://wextractor.com/api/v1/reviews/indeed"

##Specify page numbers
POSTS_PER_PAGE = 20
offset_range = [i * POSTS_PER_PAGE for i in range(0, 125)] # post ids

for offset in tqdm(offset_range, desc="Downloading data"):
    params = {
        "id": "Postmates",
        "auth_token": API_TOKEN,
        "offset": offset,
        "country": 'US'
    }

    # Make the API request
    response = requests.get(url, params=params)

    # Process the response
    if response.status_code == 200:
        data = response.json()
        ### Add to the list
        dataset.extend(data["reviews"])

    else:
        print("Error:", response.status_code)
# Out:
# Downloading data: 100%|██████████| 125/125 [04:22<00:00,  2.10s/it]

# %%
with open("indeed_%s_reviews.pkl"%params["id"], "wb") as f:
    pkl.dump(dataset, f)

# %% [markdown]
# ### Convert to Dataframe

# %%
df = pd.DataFrame(dataset).drop_duplicates(subset=['id']).set_index('id')
df = df[df["language"] == "en"]
df["state"] = df.apply(lambda x: x["location"].split(",")[-1].strip().lower(), axis=1)
df.to_csv("indeed_%s_reviews.csv" %params["id"])

# %%
df
# Out:
#                                                               title  \
# id
# 1h58962o0k7ja800                                         Fun place
# 1h4otgcarj21i801  Fun Side Job - Easy Cash for Fun but Not to Pa...
# 1h4knlsnhgfqq800  Fun job where you can make a good amount of mo...
# 1h4hqi9djk27a800              Cool until you don’t comply with vaxx
# 1h409dkphj5mt801  on the go job with lots of new learning experi...
# ...                                                             ...
# 17v303tro5n8g80j                                      Fun workplace
# 17trbgolladsg8t4              Overall, a really great place to work
# 17q85drf4b84g9jh  Friendly Work Envornment, Great Training and A...
# 17m7a84d7adsgc77  Fun place to work filled with good people and ...
# 16t9l1sv15dog8ga                             A decent place to work
#
#                                                                text rating  \
# id
# 1h58962o0k7ja800  Grub hub a fun place to work for a little extr...      4
# 1h4otgcarj21i801  I was able to use this as a side job on top of...      3
# 1h4knlsnhgfqq800  What is the best part of working at the compan...      5
# 1h4hqi9djk27a800  I liked working here up until the point the I ...      3
# 1h409dkphj5mt801      It has it's stressful moments, orders can ...      3
# ...                                                             ...    ...
# 17v303tro5n8g80j  the company had plenty of things to offer to k...      3
# 17trbgolladsg8t4  Great environment and people; Great benefits p...      4
# 17q85drf4b84g9jh  People are very friendly and nobody has a prob...      5
# 17m7a84d7adsgc77  Good co-workers and fun environment. At Grubhu...      4
# 16t9l1sv15dog8ga  In general a good place to work. A decent cult...      4
#
#                  language                                  reviewer  \
# id
# 1h58962o0k7ja800       en                           Service Advisor
# 1h4otgcarj21i801       en                           Driver/Delivery
# 1h4knlsnhgfqq800       en                           Delivery Driver
# 1h4hqi9djk27a800       en  Senior  Elite Restaurant Care Specialist
# 1h409dkphj5mt801       en                           Delivery Driver
# ...                   ...                                       ...
# 17v303tro5n8g80j       en           Customer Service Specialist lll
# 17trbgolladsg8t4       en               Customer Service Specialist
# 17q85drf4b84g9jh       en         Aliso Viejo, customer Service Rep
# 17m7a84d7adsgc77       en                          Graphic Designer
# 16t9l1sv15dog8ga       en              Manager, Database Operations
#
#                            location  \
# id
# 1h58962o0k7ja800  Central Islip, NY
# 1h4otgcarj21i801         Denver, CO
# 1h4knlsnhgfqq800         Elyria, OH
# 1h4hqi9djk27a800            Chicago
# 1h409dkphj5mt801          Salem, OR
# ...                             ...
# 17v303tro5n8g80j        Chicago, IL
# 17trbgolladsg8t4        Chicago, IL
# 17q85drf4b84g9jh     Aliso Viejo CA
# 17m7a84d7adsgc77         Chicago IL
# 16t9l1sv15dog8ga       New York, NY
#
#                                                                cons  \
# id
# 1h58962o0k7ja800
# 1h4otgcarj21i801
# 1h4knlsnhgfqq800
# 1h4hqi9djk27a800
# 1h409dkphj5mt801             a lot of technical errors with the app
# ...                                                             ...
# 17v303tro5n8g80j
# 17trbgolladsg8t4
# 17q85drf4b84g9jh  Anybody is lucky to work here. I do need more ...
# 17m7a84d7adsgc77
# 16t9l1sv15dog8ga  comp isn't always aligned with the market, no ...
#
#                                                                pros  \
# id
# 1h58962o0k7ja800
# 1h4otgcarj21i801
# 1h4knlsnhgfqq800
# 1h4hqi9djk27a800
# 1h409dkphj5mt801                                    discount on gas
# ...                                                             ...
# 17v303tro5n8g80j    Free lunch at end of week. Gift card giveaways.
# 17trbgolladsg8t4
# 17q85drf4b84g9jh                           All around great company
# 17m7a84d7adsgc77
# 16t9l1sv15dog8ga  excessive amounts of free food, work /life bal...
#
#                                                                 url  \
# id
# 1h58962o0k7ja800  https://indeed.com/cmp/Grubhub/reviews/fun-pla...
# 1h4otgcarj21i801  https://indeed.com/cmp/Grubhub/reviews/fun-sid...
# 1h4knlsnhgfqq800  https://indeed.com/cmp/Grubhub/reviews/fun-job...
# 1h4hqi9djk27a800  https://indeed.com/cmp/Grubhub/reviews/cool-un...
# 1h409dkphj5mt801  https://indeed.com/cmp/Grubhub/reviews/on-the-...
# ...                                                             ...
# 17v303tro5n8g80j  https://indeed.com/cmp/Grubhub/reviews/fun-wor...
# 17trbgolladsg8t4  https://indeed.com/cmp/Grubhub/reviews/overall...
# 17q85drf4b84g9jh  https://indeed.com/cmp/Grubhub/reviews/friendl...
# 17m7a84d7adsgc77  https://indeed.com/cmp/Grubhub/reviews/fun-pla...
# 16t9l1sv15dog8ga  https://indeed.com/cmp/Grubhub/reviews/a-decen...
#
#                              datetime reviewer_employee_type  \
# id
# 1h58962o0k7ja800  2023-07-13T00:00:00        Former Employee
# 1h4otgcarj21i801  2023-07-07T00:00:00        Former Employee
# 1h4knlsnhgfqq800  2023-07-05T00:00:00       Current Employee
# 1h4hqi9djk27a800  2023-07-04T00:00:00        Former Employee
# 1h409dkphj5mt801  2023-06-28T00:00:00       Current Employee
# ...                               ...                    ...
# 17v303tro5n8g80j  2013-07-09T00:00:00       Current Employee
# 17trbgolladsg8t4  2013-06-24T00:00:00       Current Employee
# 17q85drf4b84g9jh  2013-05-10T00:00:00       Current Employee
# 17m7a84d7adsgc77  2013-03-21T00:00:00        Former Employee
# 16t9l1sv15dog8ga  2012-05-15T00:00:00       Current Employee
#
#                  job_work_and_life_balance_rating  \
# id
# 1h58962o0k7ja800                                0
# 1h4otgcarj21i801                                0
# 1h4knlsnhgfqq800                                0
# 1h4hqi9djk27a800                                0
# 1h409dkphj5mt801                                5
# ...                                           ...
# 17v303tro5n8g80j                                1
# 17trbgolladsg8t4                                2
# 17q85drf4b84g9jh                                5
# 17m7a84d7adsgc77                                4
# 16t9l1sv15dog8ga                                5
#
#                  compensation_and_benefits_rating  \
# id
# 1h58962o0k7ja800                                0
# 1h4otgcarj21i801                                0
# 1h4knlsnhgfqq800                                0
# 1h4hqi9djk27a800                                0
# 1h409dkphj5mt801                                1
# ...                                           ...
# 17v303tro5n8g80j                                3
# 17trbgolladsg8t4                                5
# 17q85drf4b84g9jh                                5
# 17m7a84d7adsgc77                                4
# 16t9l1sv15dog8ga                                3
#
#                  job_security_and_advancement_rating management_rating  \
# id
# 1h58962o0k7ja800                                   0                 0
# 1h4otgcarj21i801                                   0                 0
# 1h4knlsnhgfqq800                                   0                 0
# 1h4hqi9djk27a800                                   0                 0
# 1h409dkphj5mt801                                   4                 3
# ...                                              ...               ...
# 17v303tro5n8g80j                                   2                 2
# 17trbgolladsg8t4                                   3                 5
# 17q85drf4b84g9jh                                   5                 5
# 17m7a84d7adsgc77                                   3                 4
# 16t9l1sv15dog8ga                                   3                 3
#
#                  job_culture_rating           state
# id
# 1h58962o0k7ja800                  0              ny
# 1h4otgcarj21i801                  0              co
# 1h4knlsnhgfqq800                  0              oh
# 1h4hqi9djk27a800                  0         chicago
# 1h409dkphj5mt801                  5              or
# ...                             ...             ...
# 17v303tro5n8g80j                  3              il
# 17trbgolladsg8t4                  3              il
# 17q85drf4b84g9jh                  5  aliso viejo ca
# 17m7a84d7adsgc77                  4      chicago il
# 16t9l1sv15dog8ga                  4              ny
#
# [684 rows x 17 columns]

# %% [markdown]
# #### Archive

# %%
# Create cloudscraper instance 
scraper = cloudscraper.create_scraper() 
# Start scrapping
for i, row in tqdm(df.iterrows(), desc="Scraping locations"):
    ###### in case of error #################
    # aka if we already have the data -> skip
    if row["raw_meta"] != "":
        continue
    #########################################
    page = scraper.get(df.loc[i, "url"])
    loc = parse(page.content)
    print(loc)
    df.loc[i, "raw_meta"] = loc
# Or: scraper = cloudscraper.CloudScraper() # CloudScraper inherits from requests.Session
# Out:
# Scraping locations: 954it [11:08,  1.87s/it]
# Feb 20, 2022 - Coordinator in Warsaw, Masovia
# Scraping locations: 955it [11:10,  1.73s/it]
# Feb 20, 2022 - Team Leader in Angeles, Pampanga
# Scraping locations: 956it [11:12,  1.80s/it]
# Feb 20, 2022 - Community Operations Manager in Sydney
# Scraping locations: 957it [11:13,  1.75s/it]
# Feb 20, 2022 - Team Lead in Phoenix, AZ
# Scraping locations: 958it [11:14,  1.59s/it]
# Feb 20, 2022 - Regional Head of Operations in Amsterdam
# Scraping locations: 959it [11:16,  1.55s/it]
# Feb 20, 2022 - Delivery Driver
# Scraping locations: 960it [11:18,  1.42it/s]
# Feb 20, 2022 - Delivery Driver

# %%
def get_location(x):
    try:
        if "in " in x:
            return x.split("in")[-1].strip()
        else: 
            return None
    except:
        return None
df["location"] = df.apply(lambda x: get_location(x["raw_meta"]), axis=1)
df.to_csv("glassdoor_2500_3500_with_loc.csv")

# %%
# Out:
# id
# 66362518               None
# 66359165               None
# 66344375    Los Angeles, CA
# 66335091       New York, NY
# 66329753               None
#                  ...
# 60008846             Sydney
# 60005224        Phoenix, AZ
# 59999562          Amsterdam
# 59999533               None
# 59996398               None
# Name: location, Length: 960, dtype: object
