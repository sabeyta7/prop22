# %%
import requests
import pickle as pkl
from time import sleep
from tqdm import tqdm
import pandas as pd 
from bs4 import BeautifulSoup
import cloudscraper 

def parse(html):
    """Parses the HTML for the price of the product."""
    soup = BeautifulSoup(html, 'html.parser')
    try:
        # Find the span element with the class "product-price"
        output = soup.find('span', class_='common__EiReviewDetailsStyle__newUiJobLine').text
        return output
    except:
        print("Error parsing for location")

# %%
API_TOKEN = input("Enter your API token: ")

# %%
dataset = []

# %% [markdown]
# ### Pool the reviews
# This code is used to pool the reviews and create a CSV file (for each company separatelly). We keep only *US-based* and *English* reviews.

# %%
url = "https://wextractor.com/api/v1/reviews/indeed"

##Specify page numbers
POSTS_PER_PAGE = 20
offset_range = [i * POSTS_PER_PAGE for i in range(0, 125)] # post ids

for offset in tqdm(offset_range, desc="Downloading data"):
    params = {
        "id": "Postmates",
        "auth_token": API_TOKEN,
        "offset": offset,
        "country": 'US'
    }

    # Make the API request
    response = requests.get(url, params=params)

    # Process the response
    if response.status_code == 200:
        data = response.json()
        ### Add to the list
        dataset.extend(data["reviews"])

    else:
        print("Error:", response.status_code)
# Out:
# Downloading data: 100%|██████████| 125/125 [04:22<00:00,  2.10s/it]

# %%
with open("indeed_%s_reviews.pkl"%params["id"], "wb") as f:
    pkl.dump(dataset, f)

# %% [markdown]
# ### Convert to Dataframe

# %%
df = pd.DataFrame(dataset).drop_duplicates(subset=['id']).set_index('id')
df = df[df["language"] == "en"]
df["state"] = df.apply(lambda x: x["location"].split(",")[-1].strip().lower(), axis=1)
df.to_csv("indeed_%s_reviews.csv" %params["id"])

# %%
df
# Out:
#                                                               title  \
# id
# 1h3thou16k27a802      A very good place to work before the merger.
# 1h2uffrq2ln2p800  Not many issues at this job, decent place to w...
# 1h2qg5bq8281h000                                                Meh
# 1h2pcpfq0ir13800                                               Fine
# 1h21f2d63ipap800  Be your boss set your own hours don’t get bett...
# ...                                                             ...
# 192lng23oak8g8k6                                   Courier Services
# 1929gco5pak8gcul  Nice idea, but you won't make $20/per hour on ...
# 18u01k0du5n8g8o2                                           creative
# 18jqqakap5n8gf7f            Fun, friendly, and wonderful team work.
# 18gkg21a9b84gcvl                                supplemental income
#
#                                                                text rating  \
# id
# 1h3thou16k27a802  This was a very good job for both IT and drive...      5
# 1h2uffrq2ln2p800  Not a bad side job, but when you add the gas p...      3
# 1h2qg5bq8281h000  Nothing too crazy about the company. Mostly us...      3
# 1h2pcpfq0ir13800  Not the best, flexible but little support. Ult...      2
# 1h21f2d63ipap800  I loved working For postmates .  I loved being...      5
# ...                                                             ...    ...
# 192lng23oak8g8k6  Courier Services. Lots of driving and discover...      3
# 1929gco5pak8gcul  I am currently an independent contractor with ...      2
# 18u01k0du5n8g8o2  We link people with products they want in less...      5
# 18jqqakap5n8gf7f  I normally work on my own hours which is on th...      5
# 18gkg21a9b84gcvl  Postmates is a platform for bike couriers to m...      4
#
#                  language                     reviewer           location  \
# id
# 1h3thou16k27a802       en  Sr. Sales Account Executive               Ohio
# 1h2uffrq2ln2p800       en       Independent Contractor      Las Vegas, NV
# 1h2qg5bq8281h000       en              Delivery Driver        Kingman, AZ
# 1h2pcpfq0ir13800       en                      Courier    Los Angeles, CA
# 1h21f2d63ipap800       en              Delivery Driver     Chesapeake, VA
# ...                   ...                          ...                ...
# 192lng23oak8g8k6       en             Courier Services         California
# 1929gco5pak8gcul       en                      Courier        Chicago, IL
# 18u01k0du5n8g8o2       en       Independent Contractor     Washington, DC
# 18jqqakap5n8gf7f       en       Independent Contractor     Washington, DC
# 18gkg21a9b84gcvl       en                      courier  San Francisco, CA
#
#                                                                cons  \
# id
# 1h3thou16k27a802                            Merger and mass layoffs
# 1h2uffrq2ln2p800       The change in payouts with almost no warning
# 1h2qg5bq8281h000
# 1h2pcpfq0ir13800
# 1h21f2d63ipap800
# ...                                                             ...
# 192lng23oak8g8k6
# 1929gco5pak8gcul  Inconsistent income and average pay that is lo...
# 18u01k0du5n8g8o2
# 18jqqakap5n8gf7f                                            On call
# 18gkg21a9b84gcvl
#
#                                                                pros  \
# id
# 1h3thou16k27a802                              Good pay, remote work
# 1h2uffrq2ln2p800  Decent schedule and an easy reach customer sup...
# 1h2qg5bq8281h000
# 1h2pcpfq0ir13800
# 1h21f2d63ipap800
# ...                                                             ...
# 192lng23oak8g8k6
# 1929gco5pak8gcul  Independent contractor so can set your own hou...
# 18u01k0du5n8g8o2
# 18jqqakap5n8gf7f          good exercise and wonderful team supports
# 18gkg21a9b84gcvl
#
#                                                                 url  \
# id
# 1h3thou16k27a802  https://indeed.com/cmp/Postmates/reviews/a-ver...
# 1h2uffrq2ln2p800  https://indeed.com/cmp/Postmates/reviews/not-m...
# 1h2qg5bq8281h000  https://indeed.com/cmp/Postmates/reviews/meh?i...
# 1h2pcpfq0ir13800  https://indeed.com/cmp/Postmates/reviews/fine?...
# 1h21f2d63ipap800  https://indeed.com/cmp/Postmates/reviews/be-yo...
# ...                                                             ...
# 192lng23oak8g8k6  https://indeed.com/cmp/Postmates/reviews/couri...
# 1929gco5pak8gcul  https://indeed.com/cmp/Postmates/reviews/nice-...
# 18u01k0du5n8g8o2  https://indeed.com/cmp/Postmates/reviews/creat...
# 18jqqakap5n8gf7f  https://indeed.com/cmp/Postmates/reviews/fun-f...
# 18gkg21a9b84gcvl  https://indeed.com/cmp/Postmates/reviews/suppl...
#
#                              datetime reviewer_employee_type  \
# id
# 1h3thou16k27a802  2023-06-26T00:00:00        Former Employee
# 1h2uffrq2ln2p800  2023-06-14T00:00:00        Former Employee
# 1h2qg5bq8281h000  2023-06-13T00:00:00        Former Employee
# 1h2pcpfq0ir13800  2023-06-12T00:00:00        Former Employee
# 1h21f2d63ipap800  2023-06-03T00:00:00        Former Employee
# ...                               ...                    ...
# 192lng23oak8g8k6  2014-09-25T00:00:00       Current Employee
# 1929gco5pak8gcul  2014-09-20T00:00:00       Current Employee
# 18u01k0du5n8g8o2  2014-07-28T00:00:00       Current Employee
# 18jqqakap5n8gf7f  2014-03-24T00:00:00       Current Employee
# 18gkg21a9b84gcvl  2014-02-12T00:00:00       Current Employee
#
#                  job_work_and_life_balance_rating  \
# id
# 1h3thou16k27a802                                5
# 1h2uffrq2ln2p800                                3
# 1h2qg5bq8281h000                                1
# 1h2pcpfq0ir13800                                0
# 1h21f2d63ipap800                                0
# ...                                           ...
# 192lng23oak8g8k6                                5
# 1929gco5pak8gcul                                2
# 18u01k0du5n8g8o2                                5
# 18jqqakap5n8gf7f                                0
# 18gkg21a9b84gcvl                                5
#
#                  compensation_and_benefits_rating  \
# id
# 1h3thou16k27a802                                5
# 1h2uffrq2ln2p800                                3
# 1h2qg5bq8281h000                                1
# 1h2pcpfq0ir13800                                0
# 1h21f2d63ipap800                                0
# ...                                           ...
# 192lng23oak8g8k6                                1
# 1929gco5pak8gcul                                2
# 18u01k0du5n8g8o2                                5
# 18jqqakap5n8gf7f                                0
# 18gkg21a9b84gcvl                                3
#
#                  job_security_and_advancement_rating management_rating  \
# id
# 1h3thou16k27a802                                   1                 1
# 1h2uffrq2ln2p800                                   3                 4
# 1h2qg5bq8281h000                                   1                 1
# 1h2pcpfq0ir13800                                   0                 0
# 1h21f2d63ipap800                                   0                 0
# ...                                              ...               ...
# 192lng23oak8g8k6                                   2                 2
# 1929gco5pak8gcul                                   4                 3
# 18u01k0du5n8g8o2                                   5                 5
# 18jqqakap5n8gf7f                                   0                 0
# 18gkg21a9b84gcvl                                   4                 4
#
#                  job_culture_rating       state
# id
# 1h3thou16k27a802                  1        ohio
# 1h2uffrq2ln2p800                  4          nv
# 1h2qg5bq8281h000                  1          az
# 1h2pcpfq0ir13800                  0          ca
# 1h21f2d63ipap800                  0          va
# ...                             ...         ...
# 192lng23oak8g8k6                  3  california
# 1929gco5pak8gcul                  4          il
# 18u01k0du5n8g8o2                  5          dc
# 18jqqakap5n8gf7f                  0          dc
# 18gkg21a9b84gcvl                  4          ca
#
# [2402 rows x 17 columns]

# %% [markdown]
# #### Archive

# %%
# Create cloudscraper instance 
scraper = cloudscraper.create_scraper() 
# Start scrapping
for i, row in tqdm(df.iterrows(), desc="Scraping locations"):
    ###### in case of error #################
    # aka if we already have the data -> skip
    if row["raw_meta"] != "":
        continue
    #########################################
    page = scraper.get(df.loc[i, "url"])
    loc = parse(page.content)
    print(loc)
    df.loc[i, "raw_meta"] = loc
# Or: scraper = cloudscraper.CloudScraper() # CloudScraper inherits from requests.Session
# Out:
# Scraping locations: 954it [11:08,  1.87s/it]
# Feb 20, 2022 - Coordinator in Warsaw, Masovia
# Scraping locations: 955it [11:10,  1.73s/it]
# Feb 20, 2022 - Team Leader in Angeles, Pampanga
# Scraping locations: 956it [11:12,  1.80s/it]
# Feb 20, 2022 - Community Operations Manager in Sydney
# Scraping locations: 957it [11:13,  1.75s/it]
# Feb 20, 2022 - Team Lead in Phoenix, AZ
# Scraping locations: 958it [11:14,  1.59s/it]
# Feb 20, 2022 - Regional Head of Operations in Amsterdam
# Scraping locations: 959it [11:16,  1.55s/it]
# Feb 20, 2022 - Delivery Driver
# Scraping locations: 960it [11:18,  1.42it/s]
# Feb 20, 2022 - Delivery Driver

# %%
def get_location(x):
    try:
        if "in " in x:
            return x.split("in")[-1].strip()
        else: 
            return None
    except:
        return None
df["location"] = df.apply(lambda x: get_location(x["raw_meta"]), axis=1)
df.to_csv("glassdoor_2500_3500_with_loc.csv")

# %%
# Out:
# id
# 66362518               None
# 66359165               None
# 66344375    Los Angeles, CA
# 66335091       New York, NY
# 66329753               None
#                  ...
# 60008846             Sydney
# 60005224        Phoenix, AZ
# 59999562          Amsterdam
# 59999533               None
# 59996398               None
# Name: location, Length: 960, dtype: object
